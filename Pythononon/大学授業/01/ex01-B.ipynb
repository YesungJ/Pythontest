# %% [markdown]
# # 2019年4月8日（月曜日）
# # プログラミングI課題
#
# 課題0 は教員と一緒に，課題1〜3 は自分で行うものとする．

# %% [markdown]
# ## 課題0
# ### 課題0-1
# 教員と一緒に　"Good morning!" と表示するプログラムを作成し実行しなさい.

# %% [markdown]
# ### 課題0-2
# 教員と一緒に，次を行いなさい．
# 1. このセルの真下に セルを追加し，その中に "1" と入力して実行する．
#  * 挿入したいセルを選択して，タブ上部のアイコン[+]を押せばそのセルの真下に新しいセルが追加される．
# 2. さらにその真下に もうひとつセルを追加し，その中に "2" と入力して実行する．
# 3. "1" と入力したセルを選択して，削除する．
#  * タブ上部のアイコン[ハサミマーク]を押せばセルを削除(切り取り)できる．

# %% [markdown]
# ### 課題0-3
# 教員と一緒に，次を行いなさい．
# 1. cntl + s を押して，このノートブックを上書き保存する．
# 2. 左のサイドバーの上部のアイコン[New Launcher] をクリックして新しいノートブックを作成する．
# 3. 作成したノートブックのタブを閉じる．
# 4. 左のサイドバーで，新しく作成されたファイル "untitiled.ipynb" を右クリック-[Rename] を選択し，ファイル名を"test.ipynb"に変更する．
# 5. 左のサイドバーで，"test.ipynb"をダブルクリックして開く.
# 6. "test.ipynb" のタブを閉じる．

# %% [markdown]
# ### 注意事項
# * 次回以降，プログラミング基礎1の講義や演習で新しくノートブックを作成したりアップロードしたりするときは，
# 左のサイドバーで "prokiso1-2019" のフォルダに移動してから行おう．
# * 左のサイドバーで上位フォルダに移動するには，上部にあるフォルダ名をクリックすれば移動できる．
#
# * **その他にも，様々な機能が JupyterLab にはある．その操作を全て講義で説明することはできないが，知っていると便利な機能も沢山あるので，家で自分で調べておこう．**

# %% [markdown]
# ## 課題1
# 高さ H，底辺の長さ L の三角形の面積を求めるプログラムを作成し実行しなさい．ただし，H と L は変数として定義し，適当な値を代入して使うこと．(教科書P.46参考)

# %% [markdown]
# ## 課題2
# プログラミング基礎Iには小テストが3回ある．Aさんの小テストの点数をそれぞれ，a1, a2, a3 とする．次の課題2-1，2-2 を行いなさい．
#
# ただし，a1, a2, a3 は変数として定義し，適当な値を代入して使うこと．
# ### 課題2-1
# Aさんの小テストの点数の総和を求めるプログラムを作成し実行しなさい．

# %% [markdown]
# ### 課題2-2
# Aさんの小テストの点数の平均点を求めるプログラムを作成し実行しなさい．

# %% [markdown]
# ## 課題3
# cntl + s を押して，このノートブックを上書き保存しなさい．
